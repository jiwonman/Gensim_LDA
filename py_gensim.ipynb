# %% [markdown]
# # Reference Site
# [참조 사이트](https://coredottoday.github.io/2018/09/17/%EB%AA%A8%EB%8D%B8-%ED%8C%8C%EB%9D%BC%EB%AF%B8%ED%84%B0-%ED%8A%9C%EB%8B%9D/)

# %% [markdown]
# # Reference Site
# [참조 사이트](https://coredottoday.github.io/2018/09/17/%EB%AA%A8%EB%8D%B8-%ED%8C%8C%EB%9D%BC%EB%AF%B8%ED%84%B0-%ED%8A%9C%EB%8B%9D/)

# %%
# Install Library 
# %pip install gensim
# %pip install --upgrade gensim==3.8.3
# %pip install pyLDAvis
# !python -m pip install -U gensim
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import Library & Load Data

import pandas as pd
from gensim import corpora
import gensim
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

df = pd.read_csv('./data/python/words.csv')

# %%
# Toknized(Series)

tokenized_doc = df['object_name'].apply(lambda x : x.split(', '))
print(tokenized_doc)
# Out:
# 0         [tree, sidewalk, building, street, wall, tree,...
# 1         [road, sidewalk, building, building, street_li...
# 2         [cubicle, table, desktop, desk, wall, dividing...
# 3         [floor, carpet, curtain, patio, window, table,...
# 4         [room, area, wall, wall, shelf, book, chair, c...
#                                 ...
# 106279    [far_right, gravel, ground, headlight, headlig...
# 106280    [beach, blue_sky, cloud, ear, face, foot, foot...
# 106281    [bell, collar, ear, ear, eye, field, grass, le...
# 106282    [bar, ceiling, door, door, platform, tail_ligh...
# 106283    [bus, desert, distance, door, door, grill, lic...
# Name: object_name, Length: 106284, dtype: object

# %%
# Make Gensim Dictionary

dictionary = corpora.Dictionary(tokenized_doc)
print(dictionary)
# Out:
# Dictionary<78166 unique tokens: ['arm', 'back', 'bike', 'building', 'car']...>

# %%
# LDA format (corpus)
corpus = [dictionary.doc2bow(text) for text in tokenized_doc]

print(corpus[0])
print(dictionary[23])
# Out:
# [(0, 1), (1, 1), (2, 2), (3, 1), (4, 2), (5, 1), (6, 1), (7, 1), (8, 1), (9, 1), (10, 1), (11, 2), (12, 2), (13, 1), (14, 1), (15, 2), (16, 1), (17, 1), (18, 1), (19, 1), (20, 2), (21, 1), (22, 1), (23, 1), (24, 1)]
# wall

# %%
# Train LDA for 20s

# Number of topics to derive
NUM_TOPICS =20

# Model Training
lda = gensim.models.ldamodel.LdaModel(corpus, num_topics=NUM_TOPICS, id2word=dictionary)
topics = lda.print_topics(num_words=4)

# num_words = 4 for topcis Distribution
for topic in topics:
    print(topic)
# Out:
# (0, '0.356*"person" + 0.064*"people" + 0.040*"jacket" + 0.036*"pant"')
# (1, '0.031*"paper" + 0.031*"laptop" + 0.029*"screen" + 0.027*"cord"')
# (2, '0.073*"plate" + 0.070*"table" + 0.068*"flower" + 0.043*"food"')
# (3, '0.327*"window" + 0.049*"cow" + 0.046*"building" + 0.044*"sheep"')
# (4, '0.100*"man" + 0.093*"shirt" + 0.067*"woman" + 0.060*"hair"')
# (5, '0.061*"tile" + 0.060*"wall" + 0.050*"handle" + 0.036*"door"')
# (6, '0.228*"cloud" + 0.122*"button" + 0.081*"sky" + 0.058*"clock"')
# (7, '0.118*"leg" + 0.104*"eye" + 0.101*"ear" + 0.069*"head"')
# (8, '0.066*"wall" + 0.036*"chair" + 0.036*"pillow" + 0.035*"picture"')
# (9, '0.177*"rock" + 0.177*"stripe" + 0.085*"number" + 0.046*"ripple"')
# (10, '0.053*"car" + 0.052*"tree" + 0.042*"snow" + 0.037*"track"')
# (11, '0.097*"sign" + 0.079*"building" + 0.058*"pole" + 0.054*"light"')
# (12, '0.190*"bird" + 0.080*"branch" + 0.063*"stick" + 0.049*"beak"')
# (13, '0.095*"train" + 0.061*"chair" + 0.059*"cat" + 0.050*"donut"')
# ...

# %%
# U_mass Coherence
cm = gensim.models.coherencemodel.CoherenceModel(model=lda, corpus=corpus, coherence='u_mass')
coherence = cm.get_coherence()
print('Cpherence', coherence)
print('\nPerplexity : ', lda.log_perplexity(corpus))
# Out:
# Cpherence -4.189034650845315
#
# Perplexity :  -9.322052446812574

# %%
# Visualization
vis = gensimvis.prepare(lda, corpus, dictionary)
pyLDAvis.save_html(vis, './data/Python/result/LDA_Visualization.html')

# Visualization to notebook
pyLDAvis.enable_notebook()
vis = gensimvis.prepare(lda, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# c:\python\lib\site-packages\pyLDAvis\_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# c:\python\lib\site-packages\pyLDAvis\_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1200011801877501602886013264"></div>
# <script type="text/javascript">
#
# ...

# %%
# Document to csv
def make_topictable_per_doc(ldamodel, corpus):
    topic_table = pd.DataFrame()

    # 몇 번째 문서인지를 의미하는 문서 번호와 해당 문서의 토픽 비중을 한 줄씩 꺼내온다.
    for i, topic_list in enumerate(ldamodel[corpus]):
        doc = topic_list[0] if ldamodel.per_word_topics else topic_list
        doc = sorted(doc, key=lambda x: (x[1]), reverse=True)
        # 각 문서에 대해서 비중이 높은 토픽순으로 토픽을 정렬한다.
        # EX) 정렬 전 0번 문서 : (2번 토픽, 48.5%), (8번 토픽, 25%), (10번 토픽, 5%), (12번 토픽, 21.5%),
        # Ex) 정렬 후 0번 문서 : (2번 토픽, 48.5%), (8번 토픽, 25%), (12번 토픽, 21.5%), (10번 토픽, 5%)
        # 48 > 25 > 21 > 5 순으로 정렬이 된 것.

        # 모든 문서에 대해서 각각 아래를 수행
        for j, (topic_num, prop_topic) in enumerate(doc):  # 몇 번 토픽인지와 비중을 나눠서 저장한다.
            if j == 0:  # 정렬을 한 상태이므로 가장 앞에 있는 것이 가장 비중이 높은 토픽
                topic_table = topic_table.append(pd.Series([int(topic_num), round(prop_topic, 4), topic_list]), ignore_index=True)
                # 가장 비중이 높은 토픽과, 가장 비중이 높은 토픽의 비중과, 전체 토픽의 비중을 저장한다.
            else:
                break
    return(topic_table)
    
topictable = make_topictable_per_doc(lda, corpus)
topictable = topictable.reset_index() # 문서 번호을 의미하는 열(column)로 사용하기 위해서 인덱스 열을 하나 더 만든다.
topictable.columns = ['문서 번호', '가장 비중이 높은 토픽', '가장 높은 토픽의 비중', '각 토픽의 비중']
print(topictable[:10])

topictable.to_csv("./data/ldamodel.csv", encoding='utf-8-sig')
# Out:
# C:\Users\UIT_421\AppData\Local\Temp\ipykernel_12000\1317089884.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   topic_table = topic_table.append(pd.Series([int(topic_num), round(prop_topic, 4), topic_list]), ignore_index=True)
# C:\Users\UIT_421\AppData\Local\Temp\ipykernel_12000\1317089884.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   topic_table = topic_table.append(pd.Series([int(topic_num), round(prop_topic, 4), topic_list]), ignore_index=True)
#    문서 번호  가장 비중이 높은 토픽  가장 높은 토픽의 비중  \
# 0      0             4        0.3691
# 1      1            11        0.8176
# 2      2             1        0.6306
# 3      3             8        0.8161
# 4      4             1        0.4282
# 5      5             2        0.5516
# 6      6             1        0.4514
# ...
